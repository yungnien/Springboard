# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r.encoding
r.encoding = 'ASCII'

# %%
print(r.encoding)
r.content
# Out:
# ASCII
# b'[{"id":"9440717528","type":"IssueCommentEvent","actor":{"id":4112568,"login":"gaetanmaisse","display_login":"gaetanmaisse","gravatar_id":"","url":"https://api.github.com/users/gaetanmaisse","avatar_url":"https://avatars.githubusercontent.com/u/4112568?"},"repo":{"id":54173593,"name":"storybooks/storybook","url":"https://api.github.com/repos/storybooks/storybook"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/storybooks/storybook/issues/6509","repository_url":"https://api.github.com/repos/storybooks/storybook","labels_url":"https://api.github.com/repos/storybooks/storybook/issues/6509/labels{/name}","comments_url":"https://api.github.com/repos/storybooks/storybook/issues/6509/comments","events_url":"https://api.github.com/repos/storybooks/storybook/issues/6509/events","html_url":"https://github.com/storybooks/storybook/pull/6509","id":432882894,"node_id":"MDExOlB1bGxSZXF1ZXN0MjcwMjQ1NDg5","number":6509,"title":"Automention for project maintainers","user":{"login":"shilman","id":488689,"node_id":"MDQ6VXNlcjQ4ODY4OQ==","avatar_url":"https://avatars2.githubusercontent.com/u/488689?v=4","gravatar_id":"","url":"https://api.github.com/users/shilman","html_url":"https://github.com/shilman","followers_url":"https://api.github.com/users/shilman/followers","following_url":"https://api.github.com/users/shilman/following{/other_user}","gists_url":"https://api.github.com/users/shilman/gists{/gist_id}","starred_url":"https://api.github.com/users/shilman/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/shilman/subscriptions","organizations_url":"https://api.github.com/users/shilman/orgs","repos_url":"https://api.github.com/users/shilman/repos","events_url":"https://api.github.com/users/shilman/events{/privacy}","received_events_url":"https://api.github.com/users/shilman/received_events","type":"User","site_admin":false},"labels":[{"id":584803996,"node_id":"MDU6TGFiZWw1ODQ4MDM5OTY=","url":"https://api.github.com/repos/storybooks/storybook/labels/addon:%20knobs","name":"addon: knobs","color":"fbca04","default":false},{"id":603502177,"node_id":"MDU6TGFiZWw2MDM1MDIxNzc=","url":"https://api.github.com/repos/storybooks/storybook/labels/app:%20react-native","name":"app: react-native","color":"f9d0c4","default":false},{"id":626669370,"node_id":"MDU6TGFiZWw2MjY2NjkzNzA=","url":"https://api.github.com/repos/storybooks/storybook/labels/app:%20vue","name":"app: vue","color":"f9d0c4","default":false},{"id":603520516,"node_id":"MDU6TGFiZWw2MDM1MjA1MTY=","url":"https://api.github.com/repos/storybooks/storybook/labels/cli","name":"cli","color":"fbca04","default":false},{"id":1136143266,"node_id":"MDU6TGFiZWwxMTM2MTQzMjY2","url":"https://api.github.com/repos/storybooks/storybook/labels/cra","name":"cra","color":"09b1ba","default":false},{"id":603489924,"node_id":"MDU6TGFiZWw2MDM0ODk5MjQ=","url":"https://api.github.com/repos/storybooks/storybook/labels/maintenance","name":"maintenance","color":"aaaaaa","default":false},{"id":1114685586,"node_id":"MDU6TGFiZWwxMTE0Njg1NTg2","url":"https://api.github.com/repos/storybooks/storybook/labels/theming","name":"theming","color":"a9f78c","default":false},{"id":885024119,"node_id":"MDU6TGFiZWw4ODUwMjQxMTk=","url":"https://api.github.com/repos/storybooks/storybook/labels/typescript","name":"typescript","color":"42e58b","default":false}],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":{"url":"https://api.github.com/repos/storybooks/storybook/milestones/14","html_url":"https://github.com/storybooks/storybook/milestone/14","labels_url":"https://api.github.com/repos/storybooks/storybook/milestones/14/labels","id":4111869,"node_id":"MDk6TWlsZXN0b25lNDExMTg2OQ==","number":14,"title":"5.0.x","description":"","creator":{"login":"shilman","id":488689,"node_id":"MDQ6VXNlcjQ4ODY4OQ==","avatar_url":"https://avatars2.githubusercontent.com/u/488689?v=4","gravatar_id":"","url":"https://api.github.com/users/shilman","html_url":"https://github.com/shilman","fo ...

# %%
r = requests.get('https://api.github.com/events', stream=True)
r.raw
r.raw.read(100)
# Out:
# b"\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xed}i\x93\xdbF\x92\xf6_a\xf4\x97\xf9`\xb1\x89\xfb\xe8\x08\xc7H#\xc9^\xcfZ\xf2\xa1\xf6\xd8\xe3\x8d\x89\x8e\x02P`CM\x12\\\x82T\x8b\xea\xf0\x7f\x7f\x9f\xc4}\x12@\x81=\xaf'\x96s\x84$\x92\x95ufVV\x1eO\xfe\xcf\xd3U\xe0]\xdd\\\xd9\x9a&\x99\xb2%\xab\xda\xd5\x8b\xab\xfdq"

# %%
import tensorflow as tf
print ("TensorFlow version: " + tf.__version__)
hello = tf.constant('Hello, TensorFlow!')
sess = tf.Session()
print(sess.run(hello))
import tensorflow.keras as keras
print(keras.__version__)
# Out:
# TensorFlow version: 1.13.1
# b'Hello, TensorFlow!'
# 2.2.4-tf

# %%
import nltk
print(nltk.__version__)
# Out:
# 3.4
